# %% [markdown]
# Class and Object
#
# - Write a Python class Car with attributes make, model, and year, and a method to display the car's details.
# - Create objects for the class and print their details

# %%
class Car:
    def __init__(self):
        self.make='mercz'
        self.model='vb32'
        self.year='2002'
    def display(self):
        print('the maker of the car ',self.make)
        print('the model of the car', self.model)
        print('the year car was made', self.year)
car1=Car()
car1.display()
# Out:
# the maker of the car  mercz
# the model of the car vb32
# the year car was made 2002

# %% [markdown]
# Encapsulation
#
# - Create a class BankAccount with private attributes _balance and methods deposit() and withdraw().
# - Ensure the balance can only be modified through these methods.

# %%
class BankAccount:
    def __init__(self):
        self.__balance=10000
        
    def deposit(self,amount):
        print('The amount is deposited')
        self.__balance=self.__balance+amount
        
    def withdraw(self,amount):
        if amount>self.__balance:
            print('Insufficient Funds')
        else:
            self.__balance=self.__balance-amount
    def currentbalance(self):
        print('Your current Balance is ', self.__balance)
bank=BankAccount()
bank.deposit(10000)
bank.withdraw(10000)
bank.currentbalance()
bank.__balance
# Out:
# The amount is deposited
# Your current Balance is  10000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 20
#      18 bank.withdraw(10000)
#      19 bank.currentbalance()
# ---> 20 bank.__balance
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %% [markdown]
# Inheritance
#
# - Design a class Animal with a method speak(). Create subclasses Dog and Cat, and override the speak() method for each.
# - Demonstrate polymorphism with these classes.

# %%
# this type of polymorphism is called method overriding which is done on subclass which has a function with same name as the parent class but different implementation
class Animal:
   
    def speak():
        pass
class Dog(Animal):
    def __init__(self,name):
        self.name=name
    def speak(self):
        print('{} barks!'.format(self.name))
class Cat(Animal):
    def __init__(self,name):
        self.name=name
    def speak(self):
        print('{} meows!'.format(self.name))

animal=Animal()
dog1=Dog('Lucky') 
dog1.speak()
cat1=Cat('Tixy')
cat1.speak()
# Out:
# Lucky barks!
# Tixy meows!

# %% [markdown]
# Polymorphism
#
# - Implement a class hierarchy with a base class Shape and derived classes Circle, Rectangle, and Triangle. Each class should have a get_area() method.
# - Use polymorphism to calculate and display areas of different shapes.

# %%
class Shape:
    def __init__(self):
        pass
    def get_area(self):
        pass
class Circle(Shape):
    def __init__(self,r):
        self.r=r
    def get_area(self):
        self.area=3.14*self.r**2
        return self.area
        #print('The area of circle is ', self.area)
        
class Rectangle(Shape):
    def __init__(self,l,b):
        self.l=l
        self.b=b
    def get_area(self):
        self.area=self.l*self.b
        return self.area
        #print('The area of the rectangle ', self.area)
class Triangle(Shape):
    def __init__(self,b,h):
        self.b=b
        self.h=h
    def get_area(self):
        self.area=0.5*self.b*self.h
        return self.area
        #print('The area of triangle ', self.area)
        
# Instantiate objects and calculate areas
shapes = [
    Circle(3),
    Rectangle(2, 3),
    Triangle(5, 10)
]

for shape in shapes:
    print(f"The area of the {shape.__class__.__name__} is {shape.get_area()}")
# Out:
# The area of the Circle is 28.26
# The area of the Rectangle is 6
# The area of the Triangle is 25.0

# %% [markdown]
# Abstraction
#
# - Define an abstract class Vehicle with an abstract method start(). Create subclasses like Bike and Car that implement the method.

# %%
from abc import ABC, abstractmethod
class Vehicle(ABC):
    def __init__(self):
        pass
    
    @abstractmethod
    def start(self):
        pass
class Bike(Vehicle):
    def start(self):
        print('the Bike starts')
class Car(Vehicle):
    def start(self):
        print('the cars starts')
        
#vehicle=Vehicle()
bike1=Bike()
bike1.start()
car1=Car()
car1.start()
# Out:
# the Bike starts
# the cars starts

# %% [markdown]
# Constructor and Destructor
#
# - Write a class Book with attributes title and author. Implement a constructor to initialize these and a destructor to display a message when the object is deleted.

# %%
class Book:
    def __init__(self,title,author):
        self.title=title
        self.author=author
    def __del__(self):
        print('The object is deleted')
book1=Book('abcd','hfwef')
del book1
# Out:
# The object is deleted

# %% [markdown]
# ## Abstract class
# - It acts as the blue print for all the subclassess
# - Any subclass of Shape is forced to implement the area and perimeter methods
# - This is particularly useful in large projects where multiple developers work on different subclasses. It avoids accidental omission of critical methods.

# %% [markdown]
# Static and Class Methods
#
# - Create a class Employee with a static method is_valid_age(age) that checks if the age is valid, and a class method from_string(emp_str) that creates an Employee object from a string like "John-30-50000".

# %%
class Employee:
    def __init__(self,name,age,pay):
        self.name=name
        self.age=age
        self.pay=pay
    
    @staticmethod
    def is_valid_age(age):
        if 22<=age<=45:
            print('Valid')
        else:
            print('Invalid')
    @classmethod
    def from_string(cls,emp_str):
        name,age,pay=emp_str.split('-')
        return cls(name,age,pay)
emp_str_1='John-30-50000'
new_emp_1=Employee.from_string(emp_str_1)
print(new_emp_1.name,new_emp_1.age)
new_emp_1.is_valid_age(40)       
print(new_emp_1.name,new_emp_1.age)
# Out:
# John 30
# Valid
# John 30

# %% [markdown]
# Operator Overloading
#
# - Overload the + operator for a class ComplexNumber to add two complex numbers.

# %%
class Complexnumber:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __add__(self, obj):
        real_sum = self.real + obj.real
        imag_sum = self.imag + obj.imag
        return Complexnumber(real_sum, imag_sum)

    def __str__(self):
        return f"{self.real} + {self.imag}i"

# Create complex number instances
cn1 = Complexnumber(2, 3)
cn2 = Complexnumber(5, 6)

# Add complex numbers
result = cn1 + cn2
print(result)
# Out:
# 7 + 9i

# %% [markdown]
# Magic Methods
#
# - Implement the __str__() and __repr__() methods for a class Student to provide meaningful string representations.

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def __repr__(self):
        return f"The name of the student is {self.name} and the marks obtained is {self.marks}"
    def __str__(self):
        return "The name is {} and the marks is {}".format(self.name,self.marks)
    
student1=Student('Radhe',90)
print(student1)
print(repr(student1))
# when we print the object the str function is called over repr. if we want to execute repr we need to repr(object).
# when str is not present repr is called
# Out:
# The name is Radhe and the marks is 90
# The name of the student is Radhe and the marks obtained is 90

# %% [markdown]
# E-Commerce System
#
# - Create a class Product with attributes like name, price, and category. Write a method to apply a discount to the product. Then, create a class Cart that maintains a list of products and calculates the total.

# %%
class Product:
    
    def __init__(self,name,price,category):
        self.name=name
        self.price=price
        self.category=category
        
    def apply_discount(self,discount):
        self.price=self.price-(self.price*discount/100)
        
class Cart(Product):
    
    def __init__(self):
        self.product_list=[]
    
    def add_product(self,product):
        self.product_list.append((product.name,product.price,product.category))
        print(f"{product.name} has been added to cart")
        
    def list_of_products(self):
        if not self.product_list:
            print('The cart is Empty')
        else:
            for product in self.product_list:
                print(f"Name:{product[0]}, Price:{product[1]}, Category:{product[2]}")
                
    def Total(self):
        sum=0
        for product in self.product_list:
            sum=sum+product[1]
        print('The total amount to be paid is ',sum)
        
        
#create products       
p1=Product('shirt',345,'clothes')
p2=Product('Pan',200,'Utensils')
p3=Product('Jeans',400,'clothes')

#create a cart and add products
cart=Cart()
cart.add_product(p1)
cart.add_product(p2)
cart.add_product(p3)

#list products in the cart and calculate the total
cart.list_of_products()
cart.Total()
# Out:
# shirt has been added to cart
# Pan has been added to cart
# Jeans has been added to cart
# Name:shirt, Price:345, Category:clothes
# Name:Pan, Price:200, Category:Utensils
# Name:Jeans, Price:400, Category:clothes
# The total amount to be paid is  945
